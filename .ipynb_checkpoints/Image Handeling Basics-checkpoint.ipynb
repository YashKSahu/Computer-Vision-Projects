# %% [markdown]
# # Image Handeling Basics

# %% [markdown]
# ## Read and Display

# %%
import cv2 as cv
import sys
from matplotlib import pyplot as plt

# %%
img = cv.imread("test_images/shop.jpg")
if img is None:
    print("Could not display image.")

# %%
# cv.imshow("Display Window",img) # Don't
plt.imshow(img,cmap="gray")
plt.title("Original Image")
plt.show()
